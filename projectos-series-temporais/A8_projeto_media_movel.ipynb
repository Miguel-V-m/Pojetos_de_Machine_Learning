# %% [markdown]
# #  <font color='DarkRed'>**PROJETO MÉDIA MÓVEL**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %% [markdown]
# ## <font color='OrangeRed'>**Análise e Tratamento Inicial**

# %%
covid = pd.read_csv('dados_covid_sp.csv',sep=';')

# %% [markdown]
# https://www.seade.gov.br/coronavirus/#
#
# https://github.com/seade-R/dados-covid-sp
#
# https://www.seade.gov.br/

# %%
covid.head(3)
# Out:
#    nome_munic  codigo_ibge  dia  mes    datahora  casos  casos_novos  \
# 0  Adamantina      3500105   25    2  2020-02-25      0            0
# 1      Adolfo      3500204   25    2  2020-02-25      0            0
# 2       Aguaí      3500303   25    2  2020-02-25      0            0
#
#                casos_pc         casos_mm7d  obitos  ...  \
# 0  0,00000000000000e+00  0,000000000000000       0  ...
# 1  0,00000000000000e+00  0,000000000000000       0  ...
# 2  0,00000000000000e+00  0,000000000000000       0  ...
#
#                 nome_drs cod_drs    pop pop_60   area  map_leg map_leg_s  \
# 0                Marília       5  33894   7398  41199        0       8.0
# 1  São José do Rio Preto      15   3447    761  21106        0       8.0
# 2  São João da Boa Vista      14  35608   5245  47455        0       8.0
#
#    latitude  longitude  semana_epidem
# 0  -21,6820   -51,0737              9
# 1  -21,2325   -49,6451              9
# 2  -22,0572   -46,9735              9
#
# [3 rows x 26 columns]

# %%
covid.shape
# Out:
# (323000, 26)

# %%
# Análise dos tipos de atributos.
# object: strings
# int64: inteiros
# float64: reais
# complex: complexos
covid.dtypes
# Out:
# nome_munic        object
# codigo_ibge        int64
# dia                int64
# mes                int64
# datahora          object
# casos              int64
# casos_novos        int64
# casos_pc          object
# casos_mm7d        object
# obitos             int64
# obitos_novos       int64
# obitos_pc         object
# obitos_mm7d       object
# letalidade        object
# nome_ra           object
# cod_ra             int64
# nome_drs          object
# cod_drs            int64
# pop                int64
# pop_60             int64
# area               int64
# map_leg           object
# map_leg_s        float64
# latitude          object
# longitude         object
# semana_epidem      int64
# dtype: object

# %%
# Substituir as vírgulas por pontos
covid['casos_mm7d'] = covid['casos_mm7d'].str.replace(',', '.')
covid
# Out:
#               nome_munic  codigo_ibge  dia  mes    datahora  casos  \
# 0             Adamantina      3500105   25    2  2020-02-25      0
# 1                 Adolfo      3500204   25    2  2020-02-25      0
# 2                  Aguaí      3500303   25    2  2020-02-25      0
# 3         Águas da Prata      3500402   25    2  2020-02-25      0
# 4       Águas de Lindóia      3500501   25    2  2020-02-25      0
# ...                  ...          ...  ...  ...         ...    ...
# 322995          Ignorado      9999999    4    7  2021-07-04    994
# 322996          Ignorado      9999999    5    7  2021-07-05    971
# 322997          Ignorado      9999999    6    7  2021-07-06    965
# 322998          Ignorado      9999999    7    7  2021-07-07    993
# 322999          Ignorado      9999999    8    7  2021-07-08    938
#
#         casos_novos              casos_pc           casos_mm7d  obitos  ...  \
# 0                 0  0,00000000000000e+00    0.000000000000000       0  ...
# 1                 0  0,00000000000000e+00    0.000000000000000       0  ...
# 2                 0  0,00000000000000e+00    0.000000000000000       0  ...
# 3                 0  0,00000000000000e+00    0.000000000000000       0  ...
# 4                 0  0,00000000000000e+00    0.000000000000000       0  ...
# ...             ...                   ...                  ...     ...  ...
# 322995          -41  0,00000000000000e+00    1.857142857142857      58  ...
# 322996          -23  0,00000000000000e+00    3.714285714285714      51  ...
# 322997           -6  0,00000000000000e+00  -14.428571428571429       8  ...
# 322998           28  0,00000000000000e+00    5.285714285714286      10  ...
# 322999          -55  0,00000000000000e+00   -4.000000000000000       0  ...
#
#                      nome_drs cod_drs    pop pop_60   area  map_leg map_leg_s  \
# 0                     Marília       5  33894   7398  41199        0       8.0
# 1       São José do Rio Preto      15   3447    761  21106        0       8.0
# 2       São João da Boa Vista      14  35608   5245  47455        0       8.0
# 3       São João da Boa Vista      14   7797   1729  14267        0       8.0
# 4                    Campinas       3  18374   3275   6013        0       8.0
# ...                       ...     ...    ...    ...    ...      ...       ...
# 322995                    NaN       0      0      0      0      NaN       NaN
# 322996                    NaN       0      0      0      0      NaN       NaN
# 322997                    NaN       0      0      0      0      NaN       NaN
# 322998                    NaN       0      0      0      0      NaN       NaN
# 322999                    NaN       0      0      0      0      NaN       NaN
#
#         latitude  longitude  semana_epidem
# 0       -21,6820   -51,0737              9
# 1       -21,2325   -49,6451              9
# 2       -22,0572   -46,9735              9
# 3       -21,9319   -46,7176              9
# 4       -22,4733   -46,6314              9
# ...          ...        ...            ...
# 322995    0,0000     0,0000             27
# 322996    0,0000     0,0000             27
# 322997    0,0000     0,0000             27
# 322998    0,0000     0,0000             27
# 322999    0,0000     0,0000             27
#
# [323000 rows x 26 columns]

# %%
# Transformar String em variável numérica
covid['casos_mm7d'] = pd.to_numeric(covid['casos_mm7d'])

# %%
covid['obitos_mm7d'] = covid['obitos_mm7d'].str.replace(',', '.')
covid
# Out:
#               nome_munic  codigo_ibge  dia  mes    datahora  casos  \
# 0             Adamantina      3500105   25    2  2020-02-25      0
# 1                 Adolfo      3500204   25    2  2020-02-25      0
# 2                  Aguaí      3500303   25    2  2020-02-25      0
# 3         Águas da Prata      3500402   25    2  2020-02-25      0
# 4       Águas de Lindóia      3500501   25    2  2020-02-25      0
# ...                  ...          ...  ...  ...         ...    ...
# 322995          Ignorado      9999999    4    7  2021-07-04    994
# 322996          Ignorado      9999999    5    7  2021-07-05    971
# 322997          Ignorado      9999999    6    7  2021-07-06    965
# 322998          Ignorado      9999999    7    7  2021-07-07    993
# 322999          Ignorado      9999999    8    7  2021-07-08    938
#
#         casos_novos              casos_pc  casos_mm7d  obitos  ...  \
# 0                 0  0,00000000000000e+00    0.000000       0  ...
# 1                 0  0,00000000000000e+00    0.000000       0  ...
# 2                 0  0,00000000000000e+00    0.000000       0  ...
# 3                 0  0,00000000000000e+00    0.000000       0  ...
# 4                 0  0,00000000000000e+00    0.000000       0  ...
# ...             ...                   ...         ...     ...  ...
# 322995          -41  0,00000000000000e+00    1.857143      58  ...
# 322996          -23  0,00000000000000e+00    3.714286      51  ...
# 322997           -6  0,00000000000000e+00  -14.428571       8  ...
# 322998           28  0,00000000000000e+00    5.285714      10  ...
# 322999          -55  0,00000000000000e+00   -4.000000       0  ...
#
#                      nome_drs cod_drs    pop pop_60   area  map_leg map_leg_s  \
# 0                     Marília       5  33894   7398  41199        0       8.0
# 1       São José do Rio Preto      15   3447    761  21106        0       8.0
# 2       São João da Boa Vista      14  35608   5245  47455        0       8.0
# 3       São João da Boa Vista      14   7797   1729  14267        0       8.0
# 4                    Campinas       3  18374   3275   6013        0       8.0
# ...                       ...     ...    ...    ...    ...      ...       ...
# 322995                    NaN       0      0      0      0      NaN       NaN
# 322996                    NaN       0      0      0      0      NaN       NaN
# 322997                    NaN       0      0      0      0      NaN       NaN
# 322998                    NaN       0      0      0      0      NaN       NaN
# 322999                    NaN       0      0      0      0      NaN       NaN
#
#         latitude  longitude  semana_epidem
# 0       -21,6820   -51,0737              9
# 1       -21,2325   -49,6451              9
# 2       -22,0572   -46,9735              9
# 3       -21,9319   -46,7176              9
# 4       -22,4733   -46,6314              9
# ...          ...        ...            ...
# 322995    0,0000     0,0000             27
# 322996    0,0000     0,0000             27
# 322997    0,0000     0,0000             27
# 322998    0,0000     0,0000             27
# 322999    0,0000     0,0000             27
#
# [323000 rows x 26 columns]

# %%
covid['obitos_mm7d'] = pd.to_numeric(covid['obitos_mm7d'])

# %%
covid.dtypes
# Out:
# nome_munic        object
# codigo_ibge        int64
# dia                int64
# mes                int64
# datahora          object
# casos              int64
# casos_novos        int64
# casos_pc          object
# casos_mm7d       float64
# obitos             int64
# obitos_novos       int64
# obitos_pc         object
# obitos_mm7d      float64
# letalidade        object
# nome_ra           object
# cod_ra             int64
# nome_drs          object
# cod_drs            int64
# pop                int64
# pop_60             int64
# area               int64
# map_leg           object
# map_leg_s        float64
# latitude          object
# longitude         object
# semana_epidem      int64
# dtype: object

# %%
covid.head()
# Out:
#          nome_munic  codigo_ibge  dia  mes    datahora  casos  casos_novos  \
# 0        Adamantina      3500105   25    2  2020-02-25      0            0
# 1            Adolfo      3500204   25    2  2020-02-25      0            0
# 2             Aguaí      3500303   25    2  2020-02-25      0            0
# 3    Águas da Prata      3500402   25    2  2020-02-25      0            0
# 4  Águas de Lindóia      3500501   25    2  2020-02-25      0            0
#
#                casos_pc  casos_mm7d  obitos  ...               nome_drs  \
# 0  0,00000000000000e+00         0.0       0  ...                Marília
# 1  0,00000000000000e+00         0.0       0  ...  São José do Rio Preto
# 2  0,00000000000000e+00         0.0       0  ...  São João da Boa Vista
# 3  0,00000000000000e+00         0.0       0  ...  São João da Boa Vista
# 4  0,00000000000000e+00         0.0       0  ...               Campinas
#
#   cod_drs    pop pop_60   area  map_leg map_leg_s  latitude  longitude  \
# 0       5  33894   7398  41199        0       8.0  -21,6820   -51,0737
# 1      15   3447    761  21106        0       8.0  -21,2325   -49,6451
# 2      14  35608   5245  47455        0       8.0  -22,0572   -46,9735
# 3      14   7797   1729  14267        0       8.0  -21,9319   -46,7176
# 4       3  18374   3275   6013        0       8.0  -22,4733   -46,6314
#
#    semana_epidem
# 0              9
# 1              9
# 2              9
# 3              9
# 4              9
#
# [5 rows x 26 columns]

# %%
covid.shape
# Out:
# (323000, 26)

# %% [markdown]
# ## <font color='OrangeRed'>**Valores Missing (NAN)**

# %%
# RELAÇÃO DA QUANTIDADE
covid.isnull().sum()
# Out:
# nome_munic         0
# codigo_ibge        0
# dia                0
# mes                0
# datahora           0
# casos              0
# casos_novos        0
# casos_pc           0
# casos_mm7d         0
# obitos             0
# obitos_novos       0
# obitos_pc          0
# obitos_mm7d        0
# letalidade         0
# nome_ra          500
# cod_ra             0
# nome_drs         500
# cod_drs            0
# pop                0
# pop_60             0
# area               0
# map_leg          500
# map_leg_s        500
# latitude           0
# longitude          0
# semana_epidem      0
# dtype: int64

# %%
# para saber o valor nulo de uma coluna é da forma:
covid['obitos'].isnull().sum()
# Out:
# 0

# %%
# Substituir valores missing por zero
covid2 = covid.fillna(0)

# %%
covid2.isnull().sum()
# Out:
# nome_munic       0
# codigo_ibge      0
# dia              0
# mes              0
# datahora         0
# casos            0
# casos_novos      0
# casos_pc         0
# casos_mm7d       0
# obitos           0
# obitos_novos     0
# obitos_pc        0
# obitos_mm7d      0
# letalidade       0
# nome_ra          0
# cod_ra           0
# nome_drs         0
# cod_drs          0
# pop              0
# pop_60           0
# area             0
# map_leg          0
# map_leg_s        0
# latitude         0
# longitude        0
# semana_epidem    0
# dtype: int64

# %%
covid2.shape
# Out:
# (323000, 26)

# %%
# EXCLUIR TODOS OS VALORES MISSING
covid3 = covid.dropna()

# %%
covid3.shape
# Out:
# (322500, 26)

# %%
covid2.dtypes
# Out:
# nome_munic        object
# codigo_ibge        int64
# dia                int64
# mes                int64
# datahora          object
# casos              int64
# casos_novos        int64
# casos_pc          object
# casos_mm7d       float64
# obitos             int64
# obitos_novos       int64
# obitos_pc         object
# obitos_mm7d      float64
# letalidade        object
# nome_ra           object
# cod_ra             int64
# nome_drs          object
# cod_drs            int64
# pop                int64
# pop_60             int64
# area               int64
# map_leg           object
# map_leg_s        float64
# latitude          object
# longitude         object
# semana_epidem      int64
# dtype: object

# %%
covid_sp = covid2.loc[covid2.nome_munic == 'São Paulo']
covid_sp.head(8)
# Out:
#      nome_munic  codigo_ibge  dia  mes    datahora  casos  casos_novos  \
# 562   São Paulo      3550308   25    2  2020-02-25      1            0
# 1207  São Paulo      3550308   26    2  2020-02-26      1            0
# 1852  São Paulo      3550308   27    2  2020-02-27      1            0
# 2497  São Paulo      3550308   28    2  2020-02-28      2            1
# 3142  São Paulo      3550308   29    2  2020-02-29      2            0
# 3787  São Paulo      3550308    1    3  2020-03-01      2            0
# 4432  São Paulo      3550308    2    3  2020-03-02      2            0
# 5077  São Paulo      3550308    3    3  2020-03-03      2            0
#
#                   casos_pc  casos_mm7d  obitos  ...          nome_drs cod_drs  \
# 562   8,42484114962012e-03    0.000000       0  ...  Grande São Paulo      10
# 1207  8,42484114962012e-03    0.000000       0  ...  Grande São Paulo      10
# 1852  8,42484114962012e-03    0.000000       0  ...  Grande São Paulo      10
# 2497  1,68496822992402e-02    0.000000       0  ...  Grande São Paulo      10
# 3142  1,68496822992402e-02    0.000000       0  ...  Grande São Paulo      10
# 3787  1,68496822992402e-02    0.000000       0  ...  Grande São Paulo      10
# 4432  1,68496822992402e-02    0.142857       0  ...  Grande São Paulo      10
# 5077  1,68496822992402e-02    0.142857       0  ...  Grande São Paulo      10
#
#            pop   pop_60    area  map_leg map_leg_s  latitude  longitude  \
# 562   11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 1207  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 1852  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 2497  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 3142  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 3787  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 4432  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 5077  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
#
#       semana_epidem
# 562               9
# 1207              9
# 1852              9
# 2497              9
# 3142              9
# 3787             10
# 4432             10
# 5077             10
#
# [8 rows x 26 columns]

# %% [markdown]
# ## <font color='OrangeRed'>**Média Móvel Casos Novos**

# %%
covid_sp.head(9)
# Out:
#      nome_munic  codigo_ibge  dia  mes    datahora  casos  casos_novos  \
# 562   São Paulo      3550308   25    2  2020-02-25      1            0
# 1207  São Paulo      3550308   26    2  2020-02-26      1            0
# 1852  São Paulo      3550308   27    2  2020-02-27      1            0
# 2497  São Paulo      3550308   28    2  2020-02-28      2            1
# 3142  São Paulo      3550308   29    2  2020-02-29      2            0
# 3787  São Paulo      3550308    1    3  2020-03-01      2            0
# 4432  São Paulo      3550308    2    3  2020-03-02      2            0
# 5077  São Paulo      3550308    3    3  2020-03-03      2            0
# 5722  São Paulo      3550308    4    3  2020-03-04      3            1
#
#                   casos_pc  casos_mm7d  obitos  ...          nome_drs cod_drs  \
# 562   8,42484114962012e-03    0.000000       0  ...  Grande São Paulo      10
# 1207  8,42484114962012e-03    0.000000       0  ...  Grande São Paulo      10
# 1852  8,42484114962012e-03    0.000000       0  ...  Grande São Paulo      10
# 2497  1,68496822992402e-02    0.000000       0  ...  Grande São Paulo      10
# 3142  1,68496822992402e-02    0.000000       0  ...  Grande São Paulo      10
# 3787  1,68496822992402e-02    0.000000       0  ...  Grande São Paulo      10
# 4432  1,68496822992402e-02    0.142857       0  ...  Grande São Paulo      10
# 5077  1,68496822992402e-02    0.142857       0  ...  Grande São Paulo      10
# 5722  2,52745234488604e-02    0.285714       0  ...  Grande São Paulo      10
#
#            pop   pop_60    area  map_leg map_leg_s  latitude  longitude  \
# 562   11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 1207  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 1852  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 2497  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 3142  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 3787  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 4432  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 5077  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
# 5722  11869660  1853286  152111      <50       7.0  -23,5329   -46,6395
#
#       semana_epidem
# 562               9
# 1207              9
# 1852              9
# 2497              9
# 3142              9
# 3787             10
# 4432             10
# 5077             10
# 5722             10
#
# [9 rows x 26 columns]

# %%
covid_sp.shape
# Out:
# (500, 26)

# %%
# Média móvel do Dataframe
plt.plot(covid_sp.casos_mm7d)
plt.title('Média Móvel - Casos Novos')
plt.grid(False)
plt.show()

# %%
serie = pd.Series(covid_sp['casos_novos'].values, index = covid_sp['datahora'])
serie
# Out:
# datahora
# 2020-02-25       0
# 2020-02-26       0
# 2020-02-27       0
# 2020-02-28       1
# 2020-02-29       0
#               ...
# 2021-07-04     706
# 2021-07-05     490
# 2021-07-06    2619
# 2021-07-07    2184
# 2021-07-08    2230
# Length: 500, dtype: int64

# %%
serie.plot();

# %%
media_casos = serie.rolling(window=7,center=True)
media_casos = media_casos.mean()

# %%
plt.plot(media_casos);

# %%
plt.plot(serie, label='Série Real')
plt.plot(media_casos,color='red', label='Média Móvel 7 dias')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## <font color='OrangeRed'>**Média Móvel Óbitos Novos**

# %%
# Média móvel do Dataframe
plt.plot(covid_sp.obitos_mm7d)
plt.title('Média Móvel - Óbitos Novos')
plt.grid(False)
plt.show()

# %%
serie = pd.Series(covid_sp['obitos_novos'].values, index = covid_sp['datahora'])
serie
# Out:
# datahora
# 2020-02-25      0
# 2020-02-26      0
# 2020-02-27      0
# 2020-02-28      0
# 2020-02-29      0
#              ...
# 2021-07-04      8
# 2021-07-05     14
# 2021-07-06    136
# 2021-07-07     88
# 2021-07-08    119
# Length: 500, dtype: int64

# %%
serie.plot();

# %%
media_obitos = serie.rolling(window=7, center=True)
media_obitos = media_obitos.mean()

# %%
plt.plot(media_obitos);

# %%
plt.plot(serie, label='Série Real')
plt.plot(media_obitos,color='red', label='Média Móvel 7 dias')
plt.legend(loc='best')
plt.show()
