# %% [markdown]
# # <font color='DarkRed'>**DECOMPOSIÇÃO**

# %% [markdown]
# ## <font color='OrangeRed'>**Concentração de CO2**

# %% [markdown]
# <font color='Navy'>**Concentração de CO2 na atmosfera em ppm de março de 1958 a dezembro de 2001 -Observatório Mauna Loa, Havaí**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
import statsmodels.api as sm

# %%
# Importação do Dataset CO2
concentracao = sm.datasets.co2.load_pandas().data
concentracao
# Out:
#               co2
# 1958-03-29  316.1
# 1958-04-05  317.3
# 1958-04-12  317.6
# 1958-04-19  317.5
# 1958-04-26  316.4
# ...           ...
# 2001-12-01  370.3
# 2001-12-08  370.8
# 2001-12-15  371.2
# 2001-12-22  371.3
# 2001-12-29  371.5
#
# [2284 rows x 1 columns]

# %%
serie = pd.Series(concentracao['co2'].values, index = concentracao.index)
serie
# Out:
# 1958-03-29    316.1
# 1958-04-05    317.3
# 1958-04-12    317.6
# 1958-04-19    317.5
# 1958-04-26    316.4
#               ...
# 2001-12-01    370.3
# 2001-12-08    370.8
# 2001-12-15    371.2
# 2001-12-22    371.3
# 2001-12-29    371.5
# Freq: W-SAT, Length: 2284, dtype: float64

# %%
serie.plot();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# podemos ver que a falta de clareza no gráfico da acima é debido a valores nulos ou missing e podemos ver:
decomposicao = seasonal_decompose(serie)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6809/3465447400.py in <module>
# ----> 1 decomposicao = seasonal_decompose(serie)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     130
#     131     if not np.all(np.isfinite(x)):
# --> 132         raise ValueError("This function does not handle missing values")
#     133     if model.startswith('m'):
#     134         if np.any(x <= 0):
#
# ValueError: This function does not handle missing values

# %%
# Analisar valores missing
concentracao.isnull().sum()
# Out:
# co2    59
# dtype: int64

# %%
# Excluir valores missing
concentracao.dropna(inplace=True)
# OU
# concentracao = concentracao.dropna()

# %%
serie = pd.Series(concentracao['co2'].values, index = concentracao.index)
serie
# Out:
# 1958-03-29    316.1
# 1958-04-05    317.3
# 1958-04-12    317.6
# 1958-04-19    317.5
# 1958-04-26    316.4
#               ...
# 2001-12-01    370.3
# 2001-12-08    370.8
# 2001-12-15    371.2
# 2001-12-22    371.3
# 2001-12-29    371.5
# Length: 2225, dtype: float64

# %%
serie.plot();

# %%
decomposicao = seasonal_decompose(serie, freq=7)

# %%
decomposicao.plot();

# %%
plt.subplot(411)
plt.plot(serie, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(decomposicao.trend, label='Tendência')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(decomposicao.seasonal,label='Sazonalidade')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(decomposicao.resid, label='Resíduos')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
decomp_mult = seasonal_decompose(serie,freq=7,model='multiplicative')

# %%
decomp_mult.plot()

# %% [markdown]
# ### <font color='DarkRed'>**DECOMPOSIÇÃO MANCHAS SOLARES 1**

# %% [markdown]
# <font color='Navy'>**Número médio mensal de manchas solares relativas de 1749 a 1983. Coletados no Observatório Federal Suíço, Zurique até 1960, e depois no Observatório Astronômico de Tóquio..**

# %%
manchas_solares = pd.read_csv('sunspots.csv')

# %%
manchas_solares
# Out:
#          x
# 1     58.0
# 2     62.6
# 3     70.0
# 4     55.7
# 5     85.0
# ...    ...
# 2816  71.8
# 2817  50.3
# 2818  55.8
# 2819  33.3
# 2820  33.4
#
# [2820 rows x 1 columns]

# %%
manchas_solares.columns = ['valores']
manchas_solares.head()
# Out:
#    valores
# 1     58.0
# 2     62.6
# 3     70.0
# 4     55.7
# 5     85.0

# %%
manchas_solares = manchas_solares.reset_index(drop=True) # drop é para excluir o índice anterior
manchas_solares
# Out:
#       valores
# 0        58.0
# 1        62.6
# 2        70.0
# 3        55.7
# 4        85.0
# ...       ...
# 2815     71.8
# 2816     50.3
# 2817     55.8
# 2818     33.3
# 2819     33.4
#
# [2820 rows x 1 columns]

# %%
indice = pd.date_range('1749', periods = len(manchas_solares), freq = 'M')
indice
# Out:
# DatetimeIndex(['1749-01-31', '1749-02-28', '1749-03-31', '1749-04-30',
#                '1749-05-31', '1749-06-30', '1749-07-31', '1749-08-31',
#                '1749-09-30', '1749-10-31',
#                ...
#                '1983-03-31', '1983-04-30', '1983-05-31', '1983-06-30',
#                '1983-07-31', '1983-08-31', '1983-09-30', '1983-10-31',
#                '1983-11-30', '1983-12-31'],
#               dtype='datetime64[ns]', length=2820, freq='M')

# %%
serie2 = pd.Series(manchas_solares['valores'].values, index = indice)

# %%
serie2.plot()
plt.show()

# %%
decomposicao2 = seasonal_decompose(serie2)

# %%
decomposicao2.plot()

# %%
decom_mult2 = seasonal_decompose(serie2,model='multiplicative')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6809/3888949154.py in <module>
# ----> 1 decom_mult2 = seasonal_decompose(serie2,model='multiplicative')
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     133     if model.startswith('m'):
#     134         if np.any(x <= 0):
# --> 135             raise ValueError("Multiplicative seasonality is not appropriate "
#     136                              "for zero and negative values")
#     137
#
# ValueError: Multiplicative seasonality is not appropriate for zero and negative values

# %% [markdown]
# ## <font color='DarkRed'>**Decomposição Manchas solares 2**

# %%
import statsmodels.api as sm

# %%
# Importação do Dataset Manchas Solares do Python
manchas_solares = sm.datasets.sunspots.load_pandas().data
manchas_solares
# Out:
#        YEAR  SUNACTIVITY
# 0    1700.0          5.0
# 1    1701.0         11.0
# 2    1702.0         16.0
# 3    1703.0         23.0
# 4    1704.0         36.0
# ..      ...          ...
# 304  2004.0         40.4
# 305  2005.0         29.8
# 306  2006.0         15.2
# 307  2007.0          7.5
# 308  2008.0          2.9
#
# [309 rows x 2 columns]

# %%
indice = pd.date_range('1700', periods = len(manchas_solares), freq = 'Y')
indice
# Out:
# DatetimeIndex(['1700-12-31', '1701-12-31', '1702-12-31', '1703-12-31',
#                '1704-12-31', '1705-12-31', '1706-12-31', '1707-12-31',
#                '1708-12-31', '1709-12-31',
#                ...
#                '1999-12-31', '2000-12-31', '2001-12-31', '2002-12-31',
#                '2003-12-31', '2004-12-31', '2005-12-31', '2006-12-31',
#                '2007-12-31', '2008-12-31'],
#               dtype='datetime64[ns]', length=309, freq='A-DEC')

# %%
serie3 = pd.Series(manchas_solares['SUNACTIVITY'].values, index = manchas_solares['YEAR'])
serie3
# Out:
# YEAR
# 1700.0     5.0
# 1701.0    11.0
# 1702.0    16.0
# 1703.0    23.0
# 1704.0    36.0
#           ...
# 2004.0    40.4
# 2005.0    29.8
# 2006.0    15.2
# 2007.0     7.5
# 2008.0     2.9
# Length: 309, dtype: float64

# %%
serie3.plot();

# %%
decomposicao3 = seasonal_decompose(serie3, freq=2)

# %%
decomposicao3.plot()
plt.show()

# %%
serie4 = pd.Series(manchas_solares['SUNACTIVITY'].values, index = indice)
serie4
# Out:
# 1700-12-31     5.0
# 1701-12-31    11.0
# 1702-12-31    16.0
# 1703-12-31    23.0
# 1704-12-31    36.0
#               ...
# 2004-12-31    40.4
# 2005-12-31    29.8
# 2006-12-31    15.2
# 2007-12-31     7.5
# 2008-12-31     2.9
# Freq: A-DEC, Length: 309, dtype: float64

# %%
serie4.plot();

# %%
decomposicao4 = seasonal_decompose(serie4,freq=3)

# %%
decomposicao4.plot()

# %% [markdown]
# https://www.w3schools.com/colors/colors_hex.asp
